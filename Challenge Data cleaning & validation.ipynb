# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams.update({'font.size': 14})

# %%
trust_data = pd.read_csv("WELLCOME_APCspend2013_forThinkful.csv", encoding ='Latin-1')

# %%
trust_data.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
newtrust_data = trust_data.dropna(axis = 0, how = 'any')
newtrust_data = newtrust_data.drop_duplicates()
newtrust_data['Journal title'] = newtrust_data.loc[:,'Journal title'].str.lower()

# %%
newtrust_data.head()
# Out:
#               PMID/PMCID Publisher                   Journal title  \
# 1             PMC3679557       ACS               biomacromolecules
# 2  23043264  PMC3506128        ACS                      j med chem
# 3    23438330 PMC3646402       ACS                      j med chem
# 4   23438216 PMC3601604        ACS                      j org chem
# 5             PMC3579457       ACS  journal of medicinal chemistry
#
#                                        Article title  \
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
# 5  Comparative Structural and Functional Studies ...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
newtrust_data.columns = ['PMID/PMCID', 'Publisher', 'JournalTitle', 'ArticleTitle', 'Cost']

# %%
newtrust_data['Cost'] = newtrust_data['Cost'].str.replace("£", "")

# %%
newtrust_data['Cost'] = newtrust_data['Cost'].str.replace("$", "")

# %%
newtrust_data['Cost'] = newtrust_data['Cost'].astype(float)

# %%
newtrust_data.count()/newtrust_data.shape[0] * 100
# Out:
# PMID/PMCID      100.0
# Publisher       100.0
# JournalTitle    100.0
# ArticleTitle    100.0
# Cost            100.0
# dtype: float64

# %%
newtrust_data['JournalTitle'].value_counts().head()
# Out:
# plos one                           188
# journal of biological chemistry     52
# neuroimage                          28
# plos pathogens                      24
# plos genetics                       23
# Name: JournalTitle, dtype: int64

# %%
cost= newtrust_data.groupby('JournalTitle').agg({'Cost':['sum', 'mean', 'std']}).reset_index()

# %%
cost['JournalTitle'].unique()
# Out:
# array(['academy of nutrition and dietetics', 'acs chemical biology',
#        'acs chemical neuroscience', 'acs nano',
#        'acta crystallographica section d,  biological crystallography ',
#        'acta crystallographica section d: biological crystallography',
#        'acta crystallographica section f: structural biology and crystallization communications',
#        'acta crystallographica, section d', 'acta crystallography d',
#        'acta d', 'acta dermato venereologica', 'acta diabetologica',
#        'acta f', 'acta neuropathol', 'acta neuropathologica',
#        'acta opthalmologica', 'acta physiol', 'addiction', 'age',
#        'age and ageing', 'aging cell', 'aids', 'aids behav', 'aids care',
#        'aids journal', 'aids research and therapy', 'aids uk',
#        'alcohol and alcoholism', 'alimentrary pharmacology & therapeutics',
#        'am j bioeth', 'am j trop med hyg',
#        'americal journal of psychiatry', 'american chemical society',
# ...

# %%
newtrust_data['subject'] = newtrust_data['JournalTitle']

# %%
newtrust_data['subject'] = newtrust_data.JournalTitle.str.replace('molecluar & cellular endocrinology', 'molecular & cellular')
newtrust_data['subject'] = newtrust_data.JournalTitle.str.replace('molecular & biochemical parasitology', 'molecular & cellular')
newtrust_data['subject'] = newtrust_data.JournalTitle.str.replace('molecular and cellular biochemistry', 'molecular & cellular')
newtrust_data['subject'] = newtrust_data.JournalTitle.str.replace('molecular & cellular proteomics', 'molecular & cellular')
newtrust_data['subject'] = newtrust_data.JournalTitle.str.replace('molecular and cellular biology', 'molecular & cellular')
newtrust_data['subject'] = newtrust_data.JournalTitle.str.replace('molecular and cellular proteomics', 'molecular & cellular')
newtrust_data['subject'] = newtrust_data.JournalTitle.str.replace('molecular cell', 'molecular & cellular')

# %%
subject = newtrust_data.groupby('subject').agg({'Cost':['sum', 'mean', 'std']}).reset_index()

# %%
subject.head()
# Out:
#                                              subject     Cost            \
#                                                           sum      mean
# 0                 academy of nutrition and dietetics  2379.54  2379.540
# 1                               acs chemical biology  6143.86  1535.965
# 2                          acs chemical neuroscience  1186.80  1186.800
# 3                                           acs nano  1336.28   668.140
# 4  acta crystallographica section d,  biological ...   771.42   771.420
#
#
#           std
# 0         NaN
# 1  500.670917
# 2         NaN
# 3   35.708892
# 4         NaN
