# %% [markdown]
# # Unit 2 Lesson 4 Multivariable regression Drill: Prepare the Data

# %%
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format

# %%
fbi_data = pd.read_csv('offenses_known_to_law_enforcement.csv')

# %%
fbi_data.head(10)
# Out:
#                        City Population Violent\ncrime  \
# 0             Adams Village      1,861              0
# 1  Addison Town and Village      2,577              3
# 2             Akron Village      2,846              3
# 3                    Albany     97,956            791
# 4            Albion Village      6,388             23
# 5            Alfred Village      4,089              5
# 6          Allegany Village      1,781              3
# 7              Amherst Town    118,296            107
# 8        Amityville Village      9,519              9
# 9                 Amsterdam     18,182             30
#
#    Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                   0.000                           nan
# 1                                   0.000                           nan
# 2                                   0.000                           nan
# 3                                   8.000                           nan
# ...

# %%
fbi_data.describe()
# Out:
#        Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# count                                 348.000                         0.000
# mean                                    1.566                           nan
# std                                    18.304                           nan
# min                                     0.000                           nan
# 25%                                     0.000                           nan
# 50%                                     0.000                           nan
# 75%                                     0.000                           nan
# max                                   335.000                           nan
#
#        Arson3  Unnamed: 13
# count 187.000        0.000
# mean    1.872          nan
# std    10.693          nan
# min     0.000          nan
# 25%     0.000          nan
# 50%     0.000          nan
# 75%     1.000          nan
# max   132.000          nan

# %%
fbi_data = fbi_data.fillna(0)

# %%
fbi_data['Murder and\nnonnegligent\nmanslaughter'] = fbi_data['Murder and\nnonnegligent\nmanslaughter'].astype(int)
fbi_data['Arson3'] = fbi_data['Arson3'].astype(int)

# %%
fbi_data = fbi_data.drop(['Unnamed: 13', 'Rape\n(revised\ndefinition)1'], axis =1)

# %%
fbi_data.head()
# Out:
#                        City Population Violent\ncrime  \
# 0             Adams Village      1,861              0
# 1  Addison Town and Village      2,577              3
# 2             Akron Village      2,846              3
# 3                    Albany     97,956            791
# 4            Albion Village      6,388             23
#
#    Murder and\nnonnegligent\nmanslaughter Rape\n(legacy\ndefinition)2 Robbery  \
# 0                                       0                           0       0
# 1                                       0                           0       0
# 2                                       0                           0       0
# 3                                       8                          30     227
# 4                                       0                           3       4
#
#   Aggravated\nassault Property\ncrime Burglary Larceny-\ntheft  \
# 0                   0              12        2              10
# ...

# %%
fbi_data['Propertycrime']= (fbi_data.population + (fbi_data.population **2) + fbi_data['Murder and\nnonnegligent\nmanslaughter'] + fbi_data.Robbery)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-6fecc125bf94> in <module>()
# ----> 1 fbi_data['Propertycrime']= (fbi_data.population + (fbi_data.population **2) + fbi_data['Murder and\nnonnegligent\nmanslaughter'] + fbi_data.Robbery)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'population'
