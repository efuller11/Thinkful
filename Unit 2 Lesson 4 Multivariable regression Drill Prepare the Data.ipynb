# %% [markdown]
# # Unit 2 Lesson 4 Multivariable regression Drill: Prepare the Data

# %%
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format
from sklearn import preprocessing

# %%
fbi_data = pd.read_csv('offenses_known_to_law_enforcement1.csv')

# %%
fbi_data.head()
# Out:
#                        City Population Violent\ncrime  \
# 0             Adams Village      1,861              0
# 1  Addison Town and Village      2,577              3
# 2             Akron Village      2,846              3
# 3                    Albany     97,956            791
# 4            Albion Village      6,388             23
#
#    Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                       0                           nan
# 1                                       0                           nan
# 2                                       0                           nan
# 3                                       8                           nan
# 4                                       0                           nan
#
#   Rape\n(legacy\ndefinition)2 Robbery Aggravated\nassault Property\ncrime  \
# 0                           0       0                   0              12
# 1                           0       0                   3              24
# 2                           0       0                   3              16
# 3                          30     227                 526           4,090
# 4                           3       4                  16             223
#
#   Burglary Larceny-\ntheft Motor\nvehicle\ntheft  Arson3
# 0        2              10                     0   0.000
# 1        3              20                     1   0.000
# 2        1              15                     0   0.000
# 3      705           3,243                   142     nan
# 4       53             165                     5     nan

# %%
fbi_data.describe()
# Out:
#        Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# count                                 348.000                         0.000
# mean                                    1.566                           nan
# std                                    18.304                           nan
# min                                     0.000                           nan
# 25%                                     0.000                           nan
# 50%                                     0.000                           nan
# 75%                                     0.000                           nan
# max                                   335.000                           nan
#
#        Arson3
# count 187.000
# mean    1.872
# std    10.693
# min     0.000
# 25%     0.000
# 50%     0.000
# 75%     1.000
# max   132.000

# %%
fbi_data = fbi_data.drop(['Rape\n(revised\ndefinition)1'], axis =1)

# %%
fbi_data.columns = ['City', 'Population', 'ViolentCrime', 'Murder', 'Rape2', 'Robbery', 'AggAssault', 'PropCrime', 'Burglary', 'Larceny', 'AutoTheft', 'Arson']

# %%
fbi_data = fbi_data.fillna(0)

# %%
fbi_data['Murder'] = fbi_data['Murder'].astype(int)
fbi_data['Arson'] = fbi_data['Arson'].astype(int)
fbi_data['Robbery'] = fbi_data['Robbery'].str.replace(',', '')
fbi_data['Population'] = fbi_data['Population'].str.replace(',', '')
fbi_data['Robbery'] = fbi_data['Robbery'].astype(int)
fbi_data['Population'] = fbi_data['Population'].astype(int)
fbi_data['PropCrime'] = fbi_data['PropCrime'].str.replace(',', '')

# %%
fbi_data['Murder'] = fbi_data['Murder'].apply(lambda x: 1 if x >= 1 else 0)
fbi_data['Robbery'] = fbi_data['Robbery'].apply(lambda x: 1 if x >= 1 else 0)

# %%
fbi_data.head()
# Out:
#                        City  Population ViolentCrime  Murder Rape2  Robbery  \
# 0             Adams Village        1861            0       0     0        0
# 1  Addison Town and Village        2577            3       0     0        0
# 2             Akron Village        2846            3       0     0        0
# 3                    Albany       97956          791       1    30        1
# 4            Albion Village        6388           23       0     3        1
#
#   AggAssault PropCrime Burglary Larceny AutoTheft  Arson
# 0          0        12        2      10         0      0
# 1          3        24        3      20         1      0
# 2          3        16        1      15         0      0
# 3        526      4090      705   3,243       142      0
# 4         16       223       53     165         5      0

# %%
regr = linear_model.LinearRegression()
Y = fbi_data['PropCrime']
X = fbi_data[['Population', 'Robbery', 'Murder']]
regr.fit(X, Y)
print('\nCoefficients: \n', regr.coef_)
print('\nIntercept: \n', regr.intercept_)
print('\nR-squared:')
print(regr.score(X, Y))
# Out:
# Coefficients:
#  [  1.68728222e-02   1.06994709e+02   6.07383740e+02]
#
# Intercept:
#  -32.7222682393
#
# R-squared:
# 0.993448543573

# %%
a = regr.intercept_
fbi_data['PropCrime'] = a + (fbi_data.Population + (fbi_data.Population **2) + fbi_data.Murder + fbi_data.Robbery)
