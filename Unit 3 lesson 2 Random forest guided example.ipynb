# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import ensemble
from sklearn.model_selection import cross_val_score

y2015 = pd.read_csv(
    'https://www.dropbox.com/s/0so14yudedjmm5m/LoanStats3d.csv?dl=1',
    skipinitialspace=True,
    header=1
)
# Out:
# C:\Users\blindside\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (0,19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
y2015.head()
# Out:
#          id   member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68009401  72868139.0    16000.0      16000.0          16000.0   60 months
# 1  68354783  73244544.0     9600.0       9600.0           9600.0   36 months
# 2  68466916  73356753.0    25000.0      25000.0          25000.0   36 months
# 3  68466961  73356799.0    28000.0      28000.0          28000.0   36 months
# 4  68495092  73384866.0     8650.0       8650.0           8650.0   36 months
#
#   int_rate  installment grade sub_grade            ...              \
# 0   14.85%       379.39     C        C5            ...
# 1    7.49%       298.58     A        A4            ...
# 2    7.49%       777.55     A        A4            ...
# 3    6.49%       858.05     A        A2            ...
# 4   19.89%       320.99     E        E3            ...
#
#   num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                0.0                2.0           78.9               0.0
# ...

# %%
y2015.tail()
# Out:
#                                                       id   member_id  \
# 421092                                          36271333  38982739.0
# 421093                                          36490806  39222577.0
# 421094                                          36271262  38982659.0
# 421095  Total amount funded in policy code 1: 6417608175         NaN
# 421096  Total amount funded in policy code 2: 1944088810         NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 421092    13000.0      13000.0          13000.0   60 months   15.99%
# 421093    12000.0      12000.0          12000.0   60 months   19.99%
# 421094    20000.0      20000.0          20000.0   36 months   11.99%
# 421095        NaN          NaN              NaN         NaN      NaN
# 421096        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade            ...              \
# 421092       316.07     D        D2            ...
# ...

# %%
y2015 = y2015[:-2]

# %%
categorical = y2015.select_dtypes(include=['object'])
for i in categorical:
    column = categorical[i]
    print(i)
    print(column.nunique())
# Out:
# id
# 421095
# term
# 2
# int_rate
# 110
# grade
# 7
# sub_grade
# 35
# emp_title
# 120812
# emp_length
# 12
# home_ownership
# 4
# verification_status
# 3
# issue_d
# 12
# loan_status
# 7
# pymnt_plan
# 1
# url
# 421095
# desc
# 34
# purpose
# 14
# title
# 27
# zip_code
# 914
# addr_state
# 49
# earliest_cr_line
# 668
# revol_util
# 1211
# initial_list_status
# 2
# last_pymnt_d
# 25
# next_pymnt_d
# 4
# last_credit_pull_d
# 26
# application_type
# 2
# verification_status_joint
# 3

# %%
# Convert ID and Interest Rate to numeric.
y2015['id'] = pd.to_numeric(y2015['id'], errors='coerce')
y2015['int_rate'] = pd.to_numeric(y2015['int_rate'].str.strip('%'), errors='coerce')

# Drop other columns with many unique variables
y2015.drop(['url', 'emp_title', 'zip_code', 'earliest_cr_line', 'revol_util',
            'sub_grade', 'addr_state', 'desc'], 1, inplace=True)

# %%
pd.get_dummies(y2015);

# %%
rfc = ensemble.RandomForestClassifier()
X = y2015.drop('loan_status', 1)
Y = y2015['loan_status']
X = pd.get_dummies(X)
X = X.dropna(axis=1)

cross_val_score(rfc, X, Y, cv=10)
# Out:
# array([ 0.98078887,  0.98038517,  0.98159626,  0.98178623,  0.97302303,
#         0.97748753,  0.93488328,  0.98066922,  0.98016957,  0.98045409])

# %%
X = y2015[['loan_amnt', 'int_rate', 'annual_inc', 'dti', 'installment',
           'term', 'pub_rec_bankruptcies', 'total_bc_limit',  'total_il_high_credit_limit']]
Y = y2015['loan_status']
X = pd.get_dummies(X)
X = X.dropna(axis=1)
cross_val_score(rfc, X, Y, cv=10)
# Out:
# array([ 0.65564817,  0.65127876,  0.65512574,  0.65301228,  0.65155545,
#         0.64880076,  0.64867368,  0.64553896,  0.64326597,  0.60048449])

# %%
X = y2015[['loan_amnt', 'int_rate', 'annual_inc', 'dti', 'installment', 'grade', 'tax_liens', 'percent_bc_gt_75', 'home_ownership'
           'term', 'pub_rec_bankruptcies', 'total_bc_limit',  'total_il_high_credit_limit', 'verification_status']]
X = pd.get_dummies(X)
X = X.dropna(axis=1)
cross_val_score(rfc, X, Y, cv=10)
# Out:
# array([ 0.66072998,  0.65135   ,  0.65586189,  0.65410463,  0.65264783,
#         0.64975065,  0.64800874,  0.64078938,  0.63777994,  0.55343656])
